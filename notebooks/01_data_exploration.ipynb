# %%
import pickle
import numpy as np

# Bir katılımcının verisini aç
with open('../data/raw/deap/s01.dat', 'rb') as f:
    data = pickle.load(f, encoding='latin1')

print("Anahtarlar:", data.keys())
print("data shape:", data['data'].shape)
print("labels shape:", data['labels'].shape)
# Out:
# Anahtarlar: dict_keys(['data', 'labels'])
# data shape: (40, 40, 8064)
# labels shape: (40, 4)

# %%
import os

print(os.listdir("../data"))
# Out:
# ['processed', 'raw']

# %%
print(os.listdir("../data/raw"))
# Out:
# ['cosubio', 'deap']
